# %% [markdown]
# # Feature Engineering

# %% [markdown]
# 1. What is a parameter?
# - In machine learning, a parameter is a variable that the model learns from the training data. For example, in a linear regression model, the slope (weights) and intercept are parameters.
#
# 2. What is correlation?
# - Correlation is a statistical measure that indicates how strongly two variables are related to each other. It ranges from -1 to 1.
#
# 3. What does negative correlation mean?
# - A negative correlation means that as one variable increases, the other decreases. For example, the number of hours spent watching TV and exam scores may have a negative correlation.
#
# 4. Define Machine Learning. What are the main components in Machine Learning?
# - Machine Learning is a field of AI that enables systems to learn from data and make predictions or decisions.
#   - Main components:
#   - Data
#   - Model
#   - Loss Function
#   - Optimizer
#   - Evaluation Metrics
#
# 5. How does loss value help in determining whether the model is good or not?
# - Loss indicates how far the predicted output is from the actual output. A lower loss value generally means a better model.
#
# 6. What are continuous and categorical variables?
# - Continuous variables: Numerical values that can take any number within a range (e.g., height, weight).
# - Categorical variables: Variables with fixed categories (e.g., gender, color).
#
# 7. How do we handle categorical variables in Machine Learning? What are the common techniques?
# - Common techniques:
#  - Label Encoding
#  - One-Hot Encoding
#  - Ordinal Encoding
#
# 8. What do you mean by training and testing a dataset?
# - Training: Used to teach the model.
# - Testing: Used to evaluate the model’s performance on unseen data.
#
# 9. What is sklearn.preprocessing?
# - A module in Scikit-learn that includes methods for scaling, transforming, and encoding data for ML models.
#
# 10. What is a Test set?
# - A subset of the data used to evaluate the model’s performance after training.
#
# 11. How do we split data for model fitting (training and testing) in Python?
# - Using train_test_split from sklearn.model_selection:
#
#  - from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# 12. How do you approach a Machine Learning problem?
# - Understand the problem
#  - Collect and clean data
#  - Perform EDA
#  - Preprocess data
#  - Choose a model
#  - Train the model
#  - Evaluate the model
#  - Improve and tune
#  - Deploy the model
#
# 13. Why do we have to perform EDA before fitting a model to the data?
# - EDA (Exploratory Data Analysis) helps understand patterns, detect outliers, identify missing values, and choose the right model and preprocessing methods.
#
# 14. What is correlation?
# - Correlation is a statistical measure that indicates how strongly two variables are related to each other. It ranges from -1 to 1.
#
# 15. What does negative correlation mean?
# - A negative correlation means that as one variable increases, the other decreases. For example, the number of hours spent watching TV and exam scores may have a negative correlation.
#
# 16. How can you find correlation between variables in Python?
# - Using .corr() with pandas:
#
#  - import pandas as pd
# df.corr()
#
# 17. What is causation? Explain difference between correlation and causation with an example.
# - Causation: One variable directly affects the other.
# - Correlation: Variables move together but one doesn’t necessarily cause the other
#  - Example: Ice cream sales and drowning incidents may be correlated (both increase in summer), but one doesn’t cause the other.
#
# 18. What is an Optimizer? What are different types of optimizers?
# - An optimizer adjusts model parameters to minimize the loss.
#
#  - Types:
#
#    - SGD (Stochastic Gradient Descent): Updates parameters for each training example.
#
#    - Adam: Combines momentum and RMSprop; adaptive learning rate.
#
#    - RMSprop: Adapts learning rate for each parameter.
#
# 19. What is sklearn.linear_model?
# - A module in Scikit-learn that contains linear models like LinearRegression, LogisticRegression, etc.
#
# 20. What does model.fit() do? What arguments must be given?
# -  It trains the model on the training data.
# Arguments: X_train, y_train.
#
# 21. What does model.predict() do? What arguments must be given?
# - It makes predictions using the trained model.
# Argument: X_test.
#
# 22. What are continuous and categorical variables?
# (Repeated) – See #6.
#
# 23. What is feature scaling? How does it help in Machine Learning?
# - Feature scaling brings all features to the same scale, which helps models converge faster and improves performance, especially for algorithms like SVM, KNN.
#
# 24. How do we perform scaling in Python?
# - Using StandardScaler or MinMaxScaler:
#  - from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)
#
# 25. What is sklearn.preprocessing?
# - A module in Scikit-learn that includes methods for scaling, transforming, and encoding data for ML models.
#
# 26. How do we split data for model fitting (training and testing) in Python?
# - Using train_test_split from sklearn.model_selection:
#
#  - from sklearn.model_selection import train_test_split
#
# 27. Explain data encoding.
# - Data encoding transforms categorical variables into numeric form so ML algorithms can process them.
#   - Types:
#    - Label Encoding
#    - One-Hot Encoding
#    - Binary Encoding
#    - Ordinal Encoding
